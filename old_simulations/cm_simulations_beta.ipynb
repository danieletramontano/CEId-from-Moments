# %%
from sympy import *
import numpy as np
import pandas as pd

from direct_lingam.simulate_data import get_Lambda, simulate_data
from direct_lingam.DAG import plot_dag
import pyximport; pyximport.install(inplace=True)
import multiprocess as mp
# import torch.multiprocessing as mp

from models import CM

# %% [markdown]
# # One Latent Variable

# %%
Lambda = get_Lambda([(2, 1)], 3)
print(f"Lambda is \n {Lambda}")
Gamma = np.array([[1], [1], [1]])
print(f"Gamma is \n {Gamma}")
highest_l = 1
plot_dag(np.hstack((Lambda, Gamma))) # Latent nodes are grey
# Out:
# Lambda is
#  [[0 0 0]
#  [0 0 0]
#  [0 1 0]]
# Gamma is
#  [[1]
#  [1]
#  [1]]

# %%
import time
def run_experiment(seed):
    # run the experiment using the given parameters
    # Set the random seed
    print(f"Running experiment with seed {seed}")
    noise_distribution = 'beta'
    samples_sizes = [10**n for n in range(1, 8, 2)]
    n_max = int(max(samples_sizes))
    # p, q = Lambda.shape[0], Lambda.shape[1]+Gamma.shape[1]
    np.random.seed(seed)
    X, true_B = simulate_data(n_max, noise_distribution=noise_distribution, Lambda=Lambda, Gamma=Gamma, permute_order=False)
    causal_effect_true = true_B[2, 1]

    # Perform the experiment
    causal_effect_estimate = []
    cross_moment_causal_effect_estimate = []
    relvlingam_causal_effect_estimate = []

    for n in samples_sizes:
        X_sample = X[:int(n), :]
        X_sample = np.asfortranarray(X_sample)
        X_sample = X_sample - np.mean(X_sample, axis=0)

        model = CM(X_sample, highest_l=highest_l)
        causal_effect_estimate.append(model.estimate_effect())
        cross_moment_causal_effect_estimate.append(model.estimate_effect_cross_moment())
        _, b_estimate = model.fit(X_sample)
        relvlingam_causal_effect_estimate.append(b_estimate[2, 1])


    # Create a DataFrame for the current seed
    seed_df = pd.DataFrame({
        'Seed': [seed] * len(samples_sizes),
        'Sample Size': samples_sizes,
        'True Effect': [causal_effect_true] * len(samples_sizes),
        'Effect Estimate': causal_effect_estimate,
        'Cross Moment Effect Estimate': cross_moment_causal_effect_estimate,
        'RelVLingam Effect Estimate': relvlingam_causal_effect_estimate
    })
    return seed_df

def parallel_simulation(reps):
    pool = mp.Pool(mp.cpu_count())
    seeds = range(reps)
    results = pool.map(run_experiment, seeds)

    pool.close()
    return pd.concat(results, ignore_index=True)

results_df = parallel_simulation(10)

def add_grica_exp(results_df):

    samples_sizes = results_df['Sample Size'].unique()
    n_max = int(max(samples_sizes))
    noise_distribution = 'beta'

    grica_causal_effect_estimate = []
    for seed in results_df['Seed'].unique():

        np.random.seed(seed)
        X, _ = simulate_data(n_max, noise_distribution=noise_distribution, Lambda=Lambda, Gamma=Gamma, permute_order=False)

        for n in samples_sizes:
            X_sample = X[:int(n), :]
            X_sample = np.asfortranarray(X_sample)
            X_sample = X_sample - np.mean(X_sample, axis=0)

            model = CM(X_sample, highest_l=highest_l)
            print("GRICA with n = ", n)
            time_start = time.time()
            if n <= 10**5:
                ce_estimate = model.estimate_effect_grica().item()
            grica_causal_effect_estimate.append(ce_estimate)
            print("Time taken: ", time.time()-time_start)

    results_df['GRICA Effect Estimate'] = grica_causal_effect_estimate
    return results_df

results_df = add_grica_exp(results_df)
# Out:
# Running experiment with seed 0Running experiment with seed 1Running experiment with seed 5Running experiment with seed 2Running experiment with seed 6Running experiment with seed 7Running experiment with seed 3Running experiment with seed 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 50
#      47     pool.close()
#      48     return pd.concat(results, ignore_index=True)
# ---> 50 results_df = parallel_simulation(10)
#      52 def add_grica_exp(results_df):
#      54     samples_sizes = results_df['Sample Size'].unique()
#
# Cell In[17], line 45, in parallel_simulation(reps)
#      43 pool = mp.Pool(mp.cpu_count())
#      44 seeds = range(reps)
# ---> 45 results = pool.map(run_experiment, seeds)
#      47 pool.close()
#      48 return pd.concat(results, ignore_index=True)
#
# File ~/Library/CloudStorage/OneDrive-TUM/Math/ReLVLiNGAM/.conda/lib/python3.11/site-packages/multiprocess/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/Library/CloudStorage/OneDrive-TUM/Math/ReLVLiNGAM/.conda/lib/python3.11/site-packages/multiprocess/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File ~/Library/CloudStorage/OneDrive-TUM/Math/ReLVLiNGAM/.conda/lib/python3.11/site-packages/multiprocess/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File ~/Library/CloudStorage/OneDrive-TUM/Math/ReLVLiNGAM/.conda/lib/python3.11/threading.py:629, in Event.wait(self, timeout)
#     627 signaled = self._flag
#     628 if not signaled:
# --> 629     signaled = self._cond.wait(timeout)
#     630 return signaled
#
# File ~/Library/CloudStorage/OneDrive-TUM/Math/ReLVLiNGAM/.conda/lib/python3.11/threading.py:327, in Condition.wait(self, timeout)
#     325 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     326     if timeout is None:
# --> 327         waiter.acquire()
#     328         gotit = True
#     329     else:
#
# KeyboardInterrupt:

# %%
# results_df.to_csv('Data/beta_cm_1_latent.csv', index=False)

# %%
# results_df = pd.read_csv('Data/beta_cm_1_latent.csv')

# %%
import matplotlib.pyplot as plt

results_df["Error"] = np.abs((results_df['Effect Estimate'] - results_df["True Effect"])/results_df["True Effect"])  # Calculate the error
results_df["Cross Moment Error"] = np.abs((results_df['Cross Moment Effect Estimate'] - results_df["True Effect"])/results_df["True Effect"])  # Calculate the error
results_df["GRICA Error"] = np.abs((results_df['GRICA Effect Estimate'] - results_df["True Effect"])/results_df["True Effect"])  # Calculate the error
results_df["RelVLingam Error"] = np.abs((results_df['RelVLingam Effect Estimate'] - results_df["True Effect"])/results_df["True Effect"])  # Calculate the error


# Group the results by sample size and calculate the mean
median_results = results_df.groupby('Sample Size').median()
quantile_results = results_df.groupby('Sample Size').quantile(0.25)
quantile_results2 = results_df.groupby('Sample Size').quantile(0.75)

SMALL_SIZE = 8
MEDIUM_SIZE = 14
BIGGER_SIZE = 16

plt.rc('font', size=BIGGER_SIZE)
plt.rc('axes', titlesize=BIGGER_SIZE)
plt.rc('axes', labelsize=BIGGER_SIZE)
plt.rc('xtick', labelsize=BIGGER_SIZE)
plt.rc('ytick', labelsize=BIGGER_SIZE)
plt.rc('legend', fontsize=MEDIUM_SIZE)
plt.rc('figure', titlesize=BIGGER_SIZE)

# Plot the results

# Plot the mean results
plt.yscale('log')
plt.xscale('log')
plt.plot(median_results.index, median_results["Error"],
         label='Cumulant',
         color = "blue")

plt.fill_between(median_results.index, quantile_results["Error"], quantile_results2["Error"], alpha=0.2, color = "blue")

plt.plot(median_results.index, median_results["Cross Moment Error"],
            label='Cross Moment',
            color = "red")

plt.fill_between(median_results.index, quantile_results["Cross Moment Error"], quantile_results2["Cross Moment Error"], alpha=0.2, color = "red")

plt.plot(median_results.index, median_results["GRICA Error"],
            label='GRICA',
            color = "green")

plt.fill_between(median_results.index, quantile_results["GRICA Error"], quantile_results2["GRICA Error"], alpha=0.2, color = "green")

plt.plot(median_results.index, median_results["RelVLingam Error"],
            label='RelVLingam',
            color = "purple")

plt.fill_between(median_results.index, quantile_results["RelVLingam Error"], quantile_results2["RelVLingam Error"], alpha=0.2, color = "purple")

plt.xlabel('Sample Size (LOG-scale)')
plt.ylabel('Error (LOG-scale)')
plt.title(f"Distribution: Beta, Graph: $\mathcal{{G}}_1$")
plt.legend()
plt.legend(loc="lower left")
plt.grid()
plt.savefig("Figures/beta_G1_samples_vs_err.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# # Two Latent Variables

# %%
Lambda = get_Lambda([(2, 1)], 3)
print(f"Lambda is \n {Lambda}")
Gamma = np.array([[1, 1], [1, 1], [1, 1]])
print(f"Gamma is \n {Gamma}")
highest_l = 2
plot_dag(np.hstack((Lambda, Gamma))) # Latent nodes are grey
# Out:
# Lambda is
#  [[0 0 0]
#  [0 0 0]
#  [0 1 0]]
# Gamma is
#  [[1 1]
#  [1 1]
#  [1 1]]

# %%
import time
def run_experiment(seed):
    # run the experiment using the given parameters
    # Set the random seed
    print(f"Running experiment with seed {seed}")
    noise_distribution = 'beta'
    samples_sizes = [10**n for n in range(1, 8, 2)]
    n_max = int(max(samples_sizes))
    # p, q = Lambda.shape[0], Lambda.shape[1]+Gamma.shape[1]
    np.random.seed(seed)
    X, true_B = simulate_data(n_max, noise_distribution=noise_distribution, Lambda=Lambda, Gamma=Gamma, permute_order=False)
    causal_effect_true = true_B[2, 1]

    # Perform the experiment
    causal_effect_estimate = []
    cross_moment_causal_effect_estimate = []
    relvlingam_causal_effect_estimate = []

    for n in samples_sizes:
        X_sample = X[:int(n), :]
        X_sample = np.asfortranarray(X_sample)
        X_sample = X_sample - np.mean(X_sample, axis=0)

        model = CM(X_sample, highest_l=highest_l)
        causal_effect_estimate.append(model.estimate_effect())
        cross_moment_causal_effect_estimate.append(model.estimate_effect_cross_moment())
        _, b_estimate = model.fit(X_sample)
        relvlingam_causal_effect_estimate.append(b_estimate[2, 1])


    # Create a DataFrame for the current seed
    seed_df = pd.DataFrame({
        'Seed': [seed] * len(samples_sizes),
        'Sample Size': samples_sizes,
        'True Effect': [causal_effect_true] * len(samples_sizes),
        'Effect Estimate': causal_effect_estimate,
        'Cross Moment Effect Estimate': cross_moment_causal_effect_estimate,
        'RelVLingam Effect Estimate': relvlingam_causal_effect_estimate
    })
    return seed_df

def parallel_simulation(reps):
    pool = mp.Pool(mp.cpu_count())
    seeds = range(reps)
    results = pool.map(run_experiment, seeds)

    pool.close()
    return pd.concat(results, ignore_index=True)

results_df_2_latents = parallel_simulation(10)

def add_grica_exp(results_df):

    samples_sizes = results_df['Sample Size'].unique()
    n_max = int(max(samples_sizes))
    noise_distribution = 'beta'

    grica_causal_effect_estimate = []
    for seed in results_df['Seed'].unique():

        np.random.seed(seed)
        X, _ = simulate_data(n_max, noise_distribution=noise_distribution, Lambda=Lambda, Gamma=Gamma, permute_order=False)

        for n in samples_sizes:
            X_sample = X[:int(n), :]
            X_sample = np.asfortranarray(X_sample)
            X_sample = X_sample - np.mean(X_sample, axis=0)

            model = CM(X_sample, highest_l=highest_l)
            print("GRICA with n = ", n)
            time_start = time.time()
            if n <= 10**5:
                ce_estimate = model.estimate_effect_grica().item()
            grica_causal_effect_estimate.append(ce_estimate)
            print("Time taken: ", time.time()-time_start)

    results_df['GRICA Effect Estimate'] = grica_causal_effect_estimate
    return results_df

results_df_2_latents = add_grica_exp(results_df_2_latents)
# Out:
# Running experiment with seed 1Running experiment with seed 3Running experiment with seed 4Running experiment with seed 2Running experiment with seed 7Running experiment with seed 5Running experiment with seed 6Running experiment with seed 0
#
#
#
#
#
#
#
# Running experiment with seed 8
# Running experiment with seed 9
# GRICA with n =  10
# Time taken:  0.10782217979431152
# GRICA with n =  1000
# Time taken:  0.11993718147277832
# GRICA with n =  100000
# Time taken:  0.8327128887176514
# GRICA with n =  10000000
# Time taken:  1.1920928955078125e-06
# GRICA with n =  10
# Time taken:  0.11124515533447266
# GRICA with n =  1000
# Time taken:  0.14585304260253906
# GRICA with n =  100000
# Time taken:  0.9310059547424316
# GRICA with n =  10000000
# Time taken:  1.1920928955078125e-06
# GRICA with n =  10
# Time taken:  0.10575103759765625
# GRICA with n =  1000
# Time taken:  0.12675094604492188
# GRICA with n =  100000
# Time taken:  0.9034938812255859
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.10584712028503418
# GRICA with n =  1000
# Time taken:  0.1184530258178711
# GRICA with n =  100000
# Time taken:  0.8689351081848145
# GRICA with n =  10000000
# Time taken:  1.1920928955078125e-06
# GRICA with n =  10
# Time taken:  0.10654687881469727
# GRICA with n =  1000
# Time taken:  0.11956286430358887
# GRICA with n =  100000
# Time taken:  0.7844219207763672
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.10593986511230469
# GRICA with n =  1000
# Time taken:  0.11867690086364746
# GRICA with n =  100000
# Time taken:  0.7814939022064209
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.11687827110290527
# GRICA with n =  1000
# Time taken:  0.11957073211669922
# GRICA with n =  100000
# Time taken:  0.8504981994628906
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.10557699203491211
# GRICA with n =  1000
# Time taken:  0.11992406845092773
# GRICA with n =  100000
# Time taken:  0.7883882522583008
# GRICA with n =  10000000
# Time taken:  1.1920928955078125e-06
# GRICA with n =  10
# Time taken:  0.10458707809448242
# GRICA with n =  1000
# Time taken:  0.11872196197509766
# GRICA with n =  100000
# Time taken:  0.8239049911499023
# GRICA with n =  10000000
# Time taken:  1.1920928955078125e-06
# GRICA with n =  10
# Time taken:  0.11203503608703613
# GRICA with n =  1000
# Time taken:  0.11899399757385254
# GRICA with n =  100000
# Time taken:  0.789841890335083
# GRICA with n =  10000000
# Time taken:  0.0
# Running experiment with seed 8
# Running experiment with seed 9

# %%
# results_df_2_latents.to_csv('Data/beta_cm_2_latent.csv', index=False)

# %%
# results_df_2_latents = pd.read_csv('Data/beta_cm_2_latent.csv')

# %%
import matplotlib.pyplot as plt

results_df_2_latents["Error"] = np.abs((results_df_2_latents['Effect Estimate'] - results_df_2_latents["True Effect"])/results_df_2_latents["True Effect"])  # Calculate the error
results_df_2_latents["Cross Moment Error"] = np.abs((results_df_2_latents['Cross Moment Effect Estimate'] - results_df_2_latents["True Effect"])/results_df_2_latents["True Effect"])  # Calculate the error
results_df_2_latents["GRICA Error"] = np.abs((results_df_2_latents['GRICA Effect Estimate'] - results_df_2_latents["True Effect"])/results_df_2_latents["True Effect"])  # Calculate the error
results_df_2_latents["RelVLingam Error"] = np.abs((results_df_2_latents['RelVLingam Effect Estimate'] - results_df_2_latents["True Effect"])/results_df_2_latents["True Effect"])  # Calculate the error

# Group the results by sample size and calculate the mean
median_results = results_df_2_latents.groupby('Sample Size').median()
quantile_results = results_df_2_latents.groupby('Sample Size').quantile(0.25)
quantile_results2 = results_df_2_latents.groupby('Sample Size').quantile(0.75)

SMALL_SIZE = 8
MEDIUM_SIZE = 14
BIGGER_SIZE = 16

plt.rc('font', size=BIGGER_SIZE)
plt.rc('axes', titlesize=BIGGER_SIZE)
plt.rc('axes', labelsize=BIGGER_SIZE)
plt.rc('xtick', labelsize=BIGGER_SIZE)
plt.rc('ytick', labelsize=BIGGER_SIZE)
plt.rc('legend', fontsize=MEDIUM_SIZE)
plt.rc('figure', titlesize=BIGGER_SIZE)

# Plot the results

# Plot the mean results
plt.yscale('log')
plt.xscale('log')
plt.plot(median_results.index, median_results["Error"],
         label='Cumulant',
         color = "blue")

plt.fill_between(median_results.index, quantile_results["Error"], quantile_results2["Error"], alpha=0.2, color = "blue")

plt.plot(median_results.index, median_results["Cross Moment Error"],
            label='Cross Moment',
            color = "red")

plt.fill_between(median_results.index, quantile_results["Cross Moment Error"], quantile_results2["Cross Moment Error"], alpha=0.2, color = "red")

plt.plot(median_results.index, median_results["GRICA Error"],
            label='GRICA',
            color = "green")

plt.fill_between(median_results.index, quantile_results["GRICA Error"], quantile_results2["GRICA Error"], alpha=0.2, color = "green")

plt.plot(median_results.index, median_results["RelVLingam Error"],
            label='RelVLingam',
            color = "purple")

plt.fill_between(median_results.index, quantile_results["RelVLingam Error"], quantile_results2["RelVLingam Error"], alpha=0.2, color = "purple")


plt.xlabel('Sample Size (LOG-scale)')
plt.ylabel('Error (LOG-scale)')
plt.title(f"Distribution: Beta, Graph: $\mathcal{{G}}_2$")
plt.legend()
plt.legend(loc="lower left")
plt.grid()
plt.savefig("Figures/beta_G2_samples_vs_err.png", bbox_inches="tight")
plt.show()

# %%
results_df_2_latents.to_csv('Data/beta_cm_2_latent.csv', index=False)
