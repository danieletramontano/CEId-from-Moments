# %%
from sympy import *
import numpy as np
import pandas as pd

from direct_lingam.simulate_data import get_Lambda, simulate_data
from direct_lingam.DAG import plot_dag
import pyximport; pyximport.install(inplace=True)
import multiprocess as mp
# import torch.multiprocessing as mp

from models import CM

# %% [markdown]
# # One Latent Variable

# %%
Lambda = get_Lambda([(2, 1)], 3)
print(f"Lambda is \n {Lambda}")
Gamma = np.array([[1], [1], [1]])
print(f"Gamma is \n {Gamma}")
highest_l = 1
plot_dag(np.hstack((Lambda, Gamma))) # Latent nodes are grey
# Out:
# Lambda is
#  [[0 0 0]
#  [0 0 0]
#  [0 1 0]]
# Gamma is
#  [[1]
#  [1]
#  [1]]

# %%
import time
def run_experiment(seed):
    # run the experiment using the given parameters
    # Set the random seed
    print(f"Running experiment with seed {seed}")
    noise_distribution = 'beta'
    samples_sizes = [10**n for n in range(1, 8, 2)]
    n_max = int(max(samples_sizes))
    # p, q = Lambda.shape[0], Lambda.shape[1]+Gamma.shape[1]
    np.random.seed(seed)
    X, true_B = simulate_data(n_max, noise_distribution=noise_distribution, Lambda=Lambda, Gamma=Gamma, permute_order=False)
    causal_effect_true = true_B[2, 1]

    # Perform the experiment
    causal_effect_estimate = []
    cross_moment_causal_effect_estimate = []

    for n in samples_sizes:
        X_sample = X[:int(n), :]
        X_sample = np.asfortranarray(X_sample)
        X_sample = X_sample - np.mean(X_sample, axis=0)

        model = CM(X_sample, highest_l=highest_l)
        causal_effect_estimate.append(model.estimate_effect())
        cross_moment_causal_effect_estimate.append(model.estimate_effect_cross_moment())

    # Create a DataFrame for the current seed
    seed_df = pd.DataFrame({
        'Seed': [seed] * len(samples_sizes),
        'Sample Size': samples_sizes,
        'True Effect': [causal_effect_true] * len(samples_sizes),
        'Effect Estimate': causal_effect_estimate,
        'Cross Moment Effect Estimate': cross_moment_causal_effect_estimate,
    })
    return seed_df

def parallel_simulation(reps):
    pool = mp.Pool(mp.cpu_count())
    seeds = range(reps)
    results = pool.map(run_experiment, seeds)

    pool.close()
    return pd.concat(results, ignore_index=True)

results_df = parallel_simulation(100)

def add_grica_exp(results_df):

    samples_sizes = results_df['Sample Size'].unique()
    n_max = int(max(samples_sizes))
    noise_distribution = 'beta'

    grica_causal_effect_estimate = []
    for seed in results_df['Seed'].unique():

        np.random.seed(seed)
        X, _ = simulate_data(n_max, noise_distribution=noise_distribution, Lambda=Lambda, Gamma=Gamma, permute_order=False)

        for n in samples_sizes:
            X_sample = X[:int(n), :]
            X_sample = np.asfortranarray(X_sample)
            X_sample = X_sample - np.mean(X_sample, axis=0)

            model = CM(X_sample, highest_l=highest_l)
            print("GRICA with n = ", n)
            time_start = time.time()
            if n <= 10**5:
                ce_estimate = model.estimate_effect_grica().item()
            grica_causal_effect_estimate.append(ce_estimate)
            print("Time taken: ", time.time()-time_start)

    results_df['GRICA Effect Estimate'] = grica_causal_effect_estimate
    return results_df

results_df = add_grica_exp(results_df)
# Out:
# Running experiment with seed 12Running experiment with seed 0Running experiment with seed 24Running experiment with seed 8Running experiment with seed 28Running experiment with seed 20Running experiment with seed 4Running experiment with seed 16
#
#
#
#
#
#
#
# Running experiment with seed 5
# Running experiment with seed 17
# Running experiment with seed 21
# Running experiment with seed 13
# Running experiment with seed 29
# Running experiment with seed 1
# Running experiment with seed 25
# Running experiment with seed 9
# Running experiment with seed 6
# Running experiment with seed 18
# Running experiment with seed 26
# Running experiment with seed 22
# Running experiment with seed 14
# Running experiment with seed 2
# Running experiment with seed 10Running experiment with seed 30
#
# Running experiment with seed 7
# Running experiment with seed 15
# Running experiment with seed 19
# Running experiment with seed 23
# Running experiment with seed 3
# Running experiment with seed 27
# Running experiment with seed 11
# Running experiment with seed 31
# Running experiment with seed 32
# Running experiment with seed 36
# Running experiment with seed 40
# Running experiment with seed 44
# Running experiment with seed 48
# Running experiment with seed 52
# Running experiment with seed 56
# Running experiment with seed 60
# Running experiment with seed 33
# Running experiment with seed 37
# Running experiment with seed 49
# Running experiment with seed 45Running experiment with seed 53
#
# Running experiment with seed 41
# Running experiment with seed 57
# Running experiment with seed 61
# Running experiment with seed 34
# Running experiment with seed 38
# Running experiment with seed 54
# Running experiment with seed 50
# Running experiment with seed 46
# Running experiment with seed 58
# Running experiment with seed 42
# Running experiment with seed 62
# Running experiment with seed 35
# Running experiment with seed 39
# Running experiment with seed 59
# Running experiment with seed 55
# Running experiment with seed 51
# Running experiment with seed 43
# Running experiment with seed 47
# Running experiment with seed 63
# Running experiment with seed 64
# Running experiment with seed 68
# Running experiment with seed 72
# Running experiment with seed 76
# Running experiment with seed 80
# Running experiment with seed 84
# Running experiment with seed 88
# Running experiment with seed 92
# Running experiment with seed 65
# Running experiment with seed 69
# Running experiment with seed 77
# Running experiment with seed 73
# Running experiment with seed 81
# Running experiment with seed 89
# Running experiment with seed 85
# Running experiment with seed 93
# Running experiment with seed 66
# Running experiment with seed 70
# Running experiment with seed 74
# Running experiment with seed 82
# Running experiment with seed 78
# Running experiment with seed 94
# Running experiment with seed 86
# Running experiment with seed 90
# Running experiment with seed 67
# Running experiment with seed 71
# Running experiment with seed 75
# Running experiment with seed 83
# Running experiment with seed 95
# Running experiment with seed 79
# Running experiment with seed 91
# Running experiment with seed 87
# Running experiment with seed 96
# Running experiment with seed 97
# Running experiment with seed 98
# Running experiment with seed 99
# GRICA with n =  10
# Time taken:  0.7309110164642334
# GRICA with n =  1000
# Time taken:  0.08984804153442383
# GRICA with n =  100000
# Time taken:  0.8091259002685547
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.13898396492004395
# GRICA with n =  1000
# Time taken:  0.09277892112731934
# GRICA with n =  100000
# Time taken:  0.723175048828125
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.12143206596374512
# GRICA with n =  1000
# Time taken:  0.09029793739318848
# GRICA with n =  100000
# Time taken:  0.7355358600616455
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.11962699890136719
# GRICA with n =  1000
# Time taken:  0.0894320011138916
# GRICA with n =  100000
# Time taken:  0.7272210121154785
# GRICA with n =  10000000
# Time taken:  7.152557373046875e-07
# GRICA with n =  10
# Time taken:  0.12220191955566406
# GRICA with n =  1000
# Time taken:  0.08902597427368164
# GRICA with n =  100000
# Time taken:  0.7339918613433838
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.1004800796508789
# GRICA with n =  1000
# Time taken:  0.09081029891967773
# GRICA with n =  100000
# Time taken:  0.7288861274719238
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.12044215202331543
# GRICA with n =  1000
# Time taken:  0.08972287178039551
# GRICA with n =  100000
# Time taken:  0.7373800277709961
# GRICA with n =  10000000
# Time taken:  1.1920928955078125e-06
# GRICA with n =  10
# Time taken:  0.11764693260192871
# GRICA with n =  1000
# Time taken:  0.09198403358459473
# GRICA with n =  100000
# Time taken:  0.7364609241485596
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.117431640625
# GRICA with n =  1000
# Time taken:  0.0904388427734375
# GRICA with n =  100000
# Time taken:  0.7313499450683594
# GRICA with n =  10000000
# Time taken:  1.1920928955078125e-06
# GRICA with n =  10
# Time taken:  0.13123822212219238
# GRICA with n =  1000
# Time taken:  0.09015703201293945
# GRICA with n =  100000
# Time taken:  0.7318649291992188
# GRICA with n =  10000000
# Time taken:  1.1920928955078125e-06
# GRICA with n =  10
# Time taken:  0.12343764305114746
# GRICA with n =  1000
# Time taken:  0.09052896499633789
# GRICA with n =  100000
# Time taken:  0.731071949005127
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.12668108940124512
# GRICA with n =  1000
# Time taken:  0.1243138313293457
# GRICA with n =  100000
# Time taken:  0.7591543197631836
# GRICA with n =  10000000
# Time taken:  7.152557373046875e-07
# GRICA with n =  10
# Time taken:  0.12200093269348145
# GRICA with n =  1000
# Time taken:  0.0922091007232666
# GRICA with n =  100000
# Time taken:  0.7292287349700928
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.12303376197814941
# GRICA with n =  1000
# Time taken:  0.08961081504821777
# GRICA with n =  100000
# Time taken:  0.7308690547943115
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.11562991142272949
# GRICA with n =  1000
# Time taken:  0.09139895439147949
# GRICA with n =  100000
# Time taken:  0.7240078449249268
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.1181800365447998
# GRICA with n =  1000
# Time taken:  0.0924232006072998
# GRICA with n =  100000
# Time taken:  0.73496413230896
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.11908793449401855
# GRICA with n =  1000
# Time taken:  0.09236979484558105
# GRICA with n =  100000
# Time taken:  0.7268967628479004
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.12764310836791992
# GRICA with n =  1000
# Time taken:  0.09004378318786621
# GRICA with n =  100000
# Time taken:  0.7246320247650146
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.11988186836242676
# GRICA with n =  1000
# Time taken:  0.09007620811462402
# GRICA with n =  100000
# Time taken:  0.725214958190918
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.1180410385131836
# GRICA with n =  1000
# Time taken:  0.0927119255065918
# GRICA with n =  100000
# Time taken:  0.7380030155181885
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.11475992202758789
# GRICA with n =  1000
# Time taken:  0.09044504165649414
# GRICA with n =  100000
# Time taken:  0.7322649955749512
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.12090682983398438
# GRICA with n =  1000
# Time taken:  0.09034323692321777
# GRICA with n =  100000
# Time taken:  0.7314159870147705
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.12426304817199707
# GRICA with n =  1000
# Time taken:  0.09428715705871582
# GRICA with n =  100000
# Time taken:  0.7311186790466309
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.11695313453674316
# GRICA with n =  1000
# Time taken:  0.13288593292236328
# GRICA with n =  100000
# Time taken:  0.7491779327392578
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.1172642707824707
# GRICA with n =  1000
# Time taken:  0.0935220718383789
# GRICA with n =  100000
# Time taken:  0.7324438095092773
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.12563490867614746
# GRICA with n =  1000
# Time taken:  0.09067416191101074
# GRICA with n =  100000
# Time taken:  0.73490309715271
# GRICA with n =  10000000
# Time taken:  7.152557373046875e-07
# GRICA with n =  10
# Time taken:  0.12555694580078125
# GRICA with n =  1000
# Time taken:  0.0890960693359375
# GRICA with n =  100000
# Time taken:  0.7332160472869873
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.12113618850708008
# GRICA with n =  1000
# Time taken:  0.08898782730102539
# GRICA with n =  100000
# Time taken:  0.7339890003204346
# GRICA with n =  10000000
# Time taken:  1.1920928955078125e-06
# GRICA with n =  10
# Time taken:  0.11822795867919922
# GRICA with n =  1000
# Time taken:  0.09219884872436523
# GRICA with n =  100000
# Time taken:  0.7403271198272705
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.11539697647094727
# GRICA with n =  1000
# Time taken:  0.09072995185852051
# GRICA with n =  100000
# Time taken:  0.7388129234313965
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.12087416648864746
# GRICA with n =  1000
# Time taken:  0.09033918380737305
# GRICA with n =  100000
# Time taken:  0.7380168437957764
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.11754393577575684
# GRICA with n =  1000
# Time taken:  0.08913207054138184
# GRICA with n =  100000
# Time taken:  0.7293040752410889
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.13282299041748047
# GRICA with n =  1000
# Time taken:  0.08972001075744629
# GRICA with n =  100000
# Time taken:  0.7442822456359863
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.15803909301757812
# GRICA with n =  1000
# Time taken:  0.10732913017272949
# GRICA with n =  100000
# Time taken:  0.8350980281829834
# GRICA with n =  10000000
# Time taken:  1.1920928955078125e-06
# GRICA with n =  10
# Time taken:  0.11650204658508301
# GRICA with n =  1000
# Time taken:  0.09197807312011719
# GRICA with n =  100000
# Time taken:  0.7322571277618408
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.1082618236541748
# GRICA with n =  1000
# Time taken:  0.09178709983825684
# GRICA with n =  100000
# Time taken:  0.7305338382720947
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.12557411193847656
# GRICA with n =  1000
# Time taken:  0.09198689460754395
# GRICA with n =  100000
# Time taken:  0.7282099723815918
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.11556196212768555
# GRICA with n =  1000
# Time taken:  0.09180402755737305
# GRICA with n =  100000
# Time taken:  0.7271161079406738
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.11355018615722656
# GRICA with n =  1000
# Time taken:  0.09105992317199707
# GRICA with n =  100000
# Time taken:  0.7359020709991455
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.1200711727142334
# GRICA with n =  1000
# Time taken:  0.09138607978820801
# GRICA with n =  100000
# Time taken:  0.7326903343200684
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.1211850643157959
# GRICA with n =  1000
# Time taken:  0.08872795104980469
# GRICA with n =  100000
# Time taken:  0.7417972087860107
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.11660408973693848
# GRICA with n =  1000
# Time taken:  0.0899198055267334
# GRICA with n =  100000
# Time taken:  0.725104808807373
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.11394500732421875
# GRICA with n =  1000
# Time taken:  0.09007000923156738
# GRICA with n =  100000
# Time taken:  0.7253921031951904
# GRICA with n =  10000000
# Time taken:  1.1920928955078125e-06
# GRICA with n =  10
# Time taken:  0.12349104881286621
# GRICA with n =  1000
# Time taken:  0.0918269157409668
# GRICA with n =  100000
# Time taken:  0.725388765335083
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.11933207511901855
# GRICA with n =  1000
# Time taken:  0.09360885620117188
# GRICA with n =  100000
# Time taken:  0.915334939956665
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.12755179405212402
# GRICA with n =  1000
# Time taken:  0.1457839012145996
# GRICA with n =  100000
# Time taken:  0.9409902095794678
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.11774086952209473
# GRICA with n =  1000
# Time taken:  0.09710574150085449
# GRICA with n =  100000
# Time taken:  0.8019587993621826
# GRICA with n =  10000000
# Time taken:  1.1920928955078125e-06
# GRICA with n =  10
# Time taken:  0.1112210750579834
# GRICA with n =  1000
# Time taken:  0.09839200973510742
# GRICA with n =  100000
# Time taken:  0.891977071762085
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.08971524238586426
# GRICA with n =  1000
# Time taken:  0.09709692001342773
# GRICA with n =  100000
# Time taken:  0.9413328170776367
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.12054014205932617
# GRICA with n =  1000
# Time taken:  0.0907599925994873
# GRICA with n =  100000
# Time taken:  0.7283551692962646
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.14656376838684082
# GRICA with n =  1000
# Time taken:  0.09396886825561523
# GRICA with n =  100000
# Time taken:  0.7892270088195801
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.12968111038208008
# GRICA with n =  1000
# Time taken:  0.0921621322631836
# GRICA with n =  100000
# Time taken:  0.7272279262542725
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.13188791275024414
# GRICA with n =  1000
# Time taken:  0.09676694869995117
# GRICA with n =  100000
# Time taken:  0.7923128604888916
# GRICA with n =  10000000
# Time taken:  1.1920928955078125e-06
# GRICA with n =  10
# Time taken:  0.08085989952087402
# GRICA with n =  1000
# Time taken:  0.09269881248474121
# GRICA with n =  100000
# Time taken:  0.8615748882293701
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.10003495216369629
# GRICA with n =  1000
# Time taken:  0.09742188453674316
# GRICA with n =  100000
# Time taken:  0.8294830322265625
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.11820387840270996
# GRICA with n =  1000
# Time taken:  0.09878277778625488
# GRICA with n =  100000
# Time taken:  0.7596628665924072
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.12232518196105957
# GRICA with n =  1000
# Time taken:  0.08916687965393066
# GRICA with n =  100000
# Time taken:  0.7315149307250977
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.13339710235595703
# GRICA with n =  1000
# Time taken:  0.09211611747741699
# GRICA with n =  100000
# Time taken:  0.7769951820373535
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.13186907768249512
# GRICA with n =  1000
# Time taken:  0.0962679386138916
# GRICA with n =  100000
# Time taken:  0.7730517387390137
# GRICA with n =  10000000
# Time taken:  1.1920928955078125e-06
# GRICA with n =  10
# Time taken:  0.11588406562805176
# GRICA with n =  1000
# Time taken:  0.09163498878479004
# GRICA with n =  100000
# Time taken:  0.7416222095489502
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.1228647232055664
# GRICA with n =  1000
# Time taken:  0.08954715728759766
# GRICA with n =  100000
# Time taken:  0.7218186855316162
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.12949204444885254
# GRICA with n =  1000
# Time taken:  0.09278297424316406
# GRICA with n =  100000
# Time taken:  0.7990841865539551
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.11786079406738281
# GRICA with n =  1000
# Time taken:  0.09081196784973145
# GRICA with n =  100000
# Time taken:  0.7244288921356201
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.12084007263183594
# GRICA with n =  1000
# Time taken:  0.0928950309753418
# GRICA with n =  100000
# Time taken:  0.7361700534820557
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.12386918067932129
# GRICA with n =  1000
# Time taken:  0.09316301345825195
# GRICA with n =  100000
# Time taken:  0.8298649787902832
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.12780117988586426
# GRICA with n =  1000
# Time taken:  0.0964212417602539
# GRICA with n =  100000
# Time taken:  0.8259119987487793
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.11677408218383789
# GRICA with n =  1000
# Time taken:  0.09066390991210938
# GRICA with n =  100000
# Time taken:  0.7275328636169434
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.1249849796295166
# GRICA with n =  1000
# Time taken:  0.10400700569152832
# GRICA with n =  100000
# Time taken:  0.7697207927703857
# GRICA with n =  10000000
# Time taken:  1.1920928955078125e-06
# GRICA with n =  10
# Time taken:  0.1219639778137207
# GRICA with n =  1000
# Time taken:  0.09583711624145508
# GRICA with n =  100000
# Time taken:  1.024827003479004
# GRICA with n =  10000000
# Time taken:  1.1920928955078125e-06
# GRICA with n =  10
# Time taken:  0.11182785034179688
# GRICA with n =  1000
# Time taken:  0.09211492538452148
# GRICA with n =  100000
# Time taken:  0.7555561065673828
# GRICA with n =  10000000
# Time taken:  7.152557373046875e-07
# GRICA with n =  10
# Time taken:  0.11873722076416016
# GRICA with n =  1000
# Time taken:  0.0916600227355957
# GRICA with n =  100000
# Time taken:  0.8601419925689697
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.11732029914855957
# GRICA with n =  1000
# Time taken:  0.09313607215881348
# GRICA with n =  100000
# Time taken:  0.7581691741943359
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.1292870044708252
# GRICA with n =  1000
# Time taken:  0.09325599670410156
# GRICA with n =  100000
# Time taken:  0.7780196666717529
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.11709213256835938
# GRICA with n =  1000
# Time taken:  0.09022021293640137
# GRICA with n =  100000
# Time taken:  0.7245640754699707
# GRICA with n =  10000000
# Time taken:  1.1920928955078125e-06
# GRICA with n =  10
# Time taken:  0.11897611618041992
# GRICA with n =  1000
# Time taken:  0.09247112274169922
# GRICA with n =  100000
# Time taken:  0.7605268955230713
# GRICA with n =  10000000
# Time taken:  0.0

# %%
results_df.to_csv('Data/beta_cm_1_latent.csv', index=False)

# %%
results_df = pd.read_csv('Data/beta_cm_1_latent.csv')

# %%
import matplotlib.pyplot as plt

results_df["Error"] = np.abs((results_df['Effect Estimate'] - results_df["True Effect"])/results_df["True Effect"])  # Calculate the error
results_df["Cross Moment Error"] = np.abs((results_df['Cross Moment Effect Estimate'] - results_df["True Effect"])/results_df["True Effect"])  # Calculate the error
results_df["GRICA Error"] = np.abs((results_df['GRICA Effect Estimate'] - results_df["True Effect"])/results_df["True Effect"])  # Calculate the error


# Group the results by sample size and calculate the mean
median_results = results_df.groupby('Sample Size').median()
quantile_results = results_df.groupby('Sample Size').quantile(0.25)
quantile_results2 = results_df.groupby('Sample Size').quantile(0.75)

SMALL_SIZE = 8
MEDIUM_SIZE = 14
BIGGER_SIZE = 16

plt.rc('font', size=BIGGER_SIZE)
plt.rc('axes', titlesize=BIGGER_SIZE)
plt.rc('axes', labelsize=BIGGER_SIZE)
plt.rc('xtick', labelsize=BIGGER_SIZE)
plt.rc('ytick', labelsize=BIGGER_SIZE)
plt.rc('legend', fontsize=MEDIUM_SIZE)
plt.rc('figure', titlesize=BIGGER_SIZE)

# Plot the results

# Plot the mean results
plt.yscale('log')
plt.xscale('log')
plt.plot(median_results.index, median_results["Error"],
         label='Cumulant',
         color = "blue")

plt.fill_between(median_results.index, quantile_results["Error"], quantile_results2["Error"], alpha=0.2, color = "blue")

plt.plot(median_results.index, median_results["Cross Moment Error"],
            label='Cross Moment',
            color = "red")

plt.fill_between(median_results.index, quantile_results["Cross Moment Error"], quantile_results2["Cross Moment Error"], alpha=0.2, color = "red")

plt.plot(median_results.index, median_results["GRICA Error"],
            label='GRICA',
            color = "green")

plt.fill_between(median_results.index, quantile_results["GRICA Error"], quantile_results2["GRICA Error"], alpha=0.2, color = "green")


plt.xlabel('Sample Size (LOG-scale)')
plt.ylabel('Error (LOG-scale)')
plt.title(f"Distribution: Beta, Graph: $\mathcal{{G}}_1$")
plt.legend()
plt.legend(loc="lower left")
plt.grid()
plt.savefig("Figures/beta_G1_samples_vs_err.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# # Two Latent Variables

# %%
Lambda = get_Lambda([(2, 1)], 3)
print(f"Lambda is \n {Lambda}")
Gamma = np.array([[1, 1], [1, 1], [1, 1]])
print(f"Gamma is \n {Gamma}")
highest_l = 2
plot_dag(np.hstack((Lambda, Gamma))) # Latent nodes are grey
# Out:
# Lambda is
#  [[0 0 0]
#  [0 0 0]
#  [0 1 0]]
# Gamma is
#  [[1 1]
#  [1 1]
#  [1 1]]

# %%
import time
def run_experiment(seed):
    # run the experiment using the given parameters
    # Set the random seed
    print(f"Running experiment with seed {seed}")
    noise_distribution = 'beta'
    samples_sizes = [10**n for n in range(1, 8, 2)]
    n_max = int(max(samples_sizes))
    # p, q = Lambda.shape[0], Lambda.shape[1]+Gamma.shape[1]
    np.random.seed(seed)
    X, true_B = simulate_data(n_max, noise_distribution=noise_distribution, Lambda=Lambda, Gamma=Gamma, permute_order=False)
    causal_effect_true = true_B[2, 1]

    # Perform the experiment
    causal_effect_estimate = []
    cross_moment_causal_effect_estimate = []

    for n in samples_sizes:
        X_sample = X[:int(n), :]
        X_sample = np.asfortranarray(X_sample)
        X_sample = X_sample - np.mean(X_sample, axis=0)

        model = CM(X_sample, highest_l=highest_l)
        causal_effect_estimate.append(model.estimate_effect())
        cross_moment_causal_effect_estimate.append(model.estimate_effect_cross_moment())

    # Create a DataFrame for the current seed
    seed_df = pd.DataFrame({
        'Seed': [seed] * len(samples_sizes),
        'Sample Size': samples_sizes,
        'True Effect': [causal_effect_true] * len(samples_sizes),
        'Effect Estimate': causal_effect_estimate,
        'Cross Moment Effect Estimate': cross_moment_causal_effect_estimate,
    })
    return seed_df

def parallel_simulation(reps):
    pool = mp.Pool(mp.cpu_count())
    seeds = range(reps)
    results = pool.map(run_experiment, seeds)

    pool.close()
    return pd.concat(results, ignore_index=True)

results_df_2_latents = parallel_simulation(100)

def add_grica_exp(results_df):

    samples_sizes = results_df['Sample Size'].unique()
    n_max = int(max(samples_sizes))
    noise_distribution = 'beta'

    grica_causal_effect_estimate = []
    for seed in results_df['Seed'].unique():

        np.random.seed(seed)
        X, _ = simulate_data(n_max, noise_distribution=noise_distribution, Lambda=Lambda, Gamma=Gamma, permute_order=False)

        for n in samples_sizes:
            X_sample = X[:int(n), :]
            X_sample = np.asfortranarray(X_sample)
            X_sample = X_sample - np.mean(X_sample, axis=0)

            model = CM(X_sample, highest_l=highest_l)
            print("GRICA with n = ", n)
            time_start = time.time()
            if n <= 10**5:
                ce_estimate = model.estimate_effect_grica().item()
            grica_causal_effect_estimate.append(ce_estimate)
            print("Time taken: ", time.time()-time_start)

    results_df['GRICA Effect Estimate'] = grica_causal_effect_estimate
    return results_df

results_df_2_latents = add_grica_exp(results_df_2_latents)
# Out:
# Running experiment with seed 0Running experiment with seed 4Running experiment with seed 8Running experiment with seed 12Running experiment with seed 20Running experiment with seed 16Running experiment with seed 24Running experiment with seed 28
#
#
#
#
#
#
#
# Running experiment with seed 29
# Running experiment with seed 5
# Running experiment with seed 25
# Running experiment with seed 21
# Running experiment with seed 13
# Running experiment with seed 9
# Running experiment with seed 17
# Running experiment with seed 1
# Running experiment with seed 30
# Running experiment with seed 6
# Running experiment with seed 10
# Running experiment with seed 26
# Running experiment with seed 22
# Running experiment with seed 14
# Running experiment with seed 2
# Running experiment with seed 18
# Running experiment with seed 31
# Running experiment with seed 7
# Running experiment with seed 11
# Running experiment with seed 27
# Running experiment with seed 15
# Running experiment with seed 3
# Running experiment with seed 19
# Running experiment with seed 23
# Running experiment with seed 32
# Running experiment with seed 36
# Running experiment with seed 40
# Running experiment with seed 44
# Running experiment with seed 48
# Running experiment with seed 52
# Running experiment with seed 56
# Running experiment with seed 60
# Running experiment with seed 33
# Running experiment with seed 37
# Running experiment with seed 41
# Running experiment with seed 45
# Running experiment with seed 53
# Running experiment with seed 57
# Running experiment with seed 49
# Running experiment with seed 61
# Running experiment with seed 34
# Running experiment with seed 38
# Running experiment with seed 42
# Running experiment with seed 46
# Running experiment with seed 58
# Running experiment with seed 54
# Running experiment with seed 50
# Running experiment with seed 62
# Running experiment with seed 35
# Running experiment with seed 39
# Running experiment with seed 43
# Running experiment with seed 47
# Running experiment with seed 59
# Running experiment with seed 51
# Running experiment with seed 55
# Running experiment with seed 63
# Running experiment with seed 64
# Running experiment with seed 68
# Running experiment with seed 72
# Running experiment with seed 76
# Running experiment with seed 80
# Running experiment with seed 84
# Running experiment with seed 88
# Running experiment with seed 92
# Running experiment with seed 65
# Running experiment with seed 69
# Running experiment with seed 73
# Running experiment with seed 77
# Running experiment with seed 81
# Running experiment with seed 85
# Running experiment with seed 89
# Running experiment with seed 93
# Running experiment with seed 66
# Running experiment with seed 70
# Running experiment with seed 74
# Running experiment with seed 78
# Running experiment with seed 82
# Running experiment with seed 90
# Running experiment with seed 86
# Running experiment with seed 94
# Running experiment with seed 67
# Running experiment with seed 71
# Running experiment with seed 75
# Running experiment with seed 79
# Running experiment with seed 83
# Running experiment with seed 91
# Running experiment with seed 87
# Running experiment with seed 95
# Running experiment with seed 96
# Running experiment with seed 97
# Running experiment with seed 98
# Running experiment with seed 99
# GRICA with n =  10
# Time taken:  0.10796022415161133
# GRICA with n =  1000
# Time taken:  0.11892294883728027
# GRICA with n =  100000
# Time taken:  0.8274109363555908
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.10230779647827148
# GRICA with n =  1000
# Time taken:  0.11481189727783203
# GRICA with n =  100000
# Time taken:  0.7793726921081543
# GRICA with n =  10000000
# Time taken:  1.1920928955078125e-06
# GRICA with n =  10
# Time taken:  0.10259199142456055
# GRICA with n =  1000
# Time taken:  0.1195228099822998
# GRICA with n =  100000
# Time taken:  0.772169828414917
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.10632896423339844
# GRICA with n =  1000
# Time taken:  0.11778426170349121
# GRICA with n =  100000
# Time taken:  0.8539221286773682
# GRICA with n =  10000000
# Time taken:  1.1920928955078125e-06
# GRICA with n =  10
# Time taken:  0.10248589515686035
# GRICA with n =  1000
# Time taken:  0.11652708053588867
# GRICA with n =  100000
# Time taken:  0.7833840847015381
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.11252593994140625
# GRICA with n =  1000
# Time taken:  0.1175379753112793
# GRICA with n =  100000
# Time taken:  0.8175930976867676
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.10067892074584961
# GRICA with n =  1000
# Time taken:  0.11882805824279785
# GRICA with n =  100000
# Time taken:  0.8654978275299072
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.11317300796508789
# GRICA with n =  1000
# Time taken:  0.1136620044708252
# GRICA with n =  100000
# Time taken:  0.837205171585083
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.10074305534362793
# GRICA with n =  1000
# Time taken:  0.1143348217010498
# GRICA with n =  100000
# Time taken:  0.8802411556243896
# GRICA with n =  10000000
# Time taken:  7.152557373046875e-07
# GRICA with n =  10
# Time taken:  0.10645794868469238
# GRICA with n =  1000
# Time taken:  0.11425113677978516
# GRICA with n =  100000
# Time taken:  0.75547194480896
# GRICA with n =  10000000
# Time taken:  1.1920928955078125e-06
# GRICA with n =  10
# Time taken:  0.10157585144042969
# GRICA with n =  1000
# Time taken:  0.1569380760192871
# GRICA with n =  100000
# Time taken:  0.7620079517364502
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.10563802719116211
# GRICA with n =  1000
# Time taken:  0.1180410385131836
# GRICA with n =  100000
# Time taken:  0.752500057220459
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.1042029857635498
# GRICA with n =  1000
# Time taken:  0.11300921440124512
# GRICA with n =  100000
# Time taken:  0.761040210723877
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.11081218719482422
# GRICA with n =  1000
# Time taken:  0.11405205726623535
# GRICA with n =  100000
# Time taken:  0.7794017791748047
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.11543488502502441
# GRICA with n =  1000
# Time taken:  0.12001991271972656
# GRICA with n =  100000
# Time taken:  0.7920949459075928
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.10171866416931152
# GRICA with n =  1000
# Time taken:  0.11901402473449707
# GRICA with n =  100000
# Time taken:  0.7712550163269043
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.1008157730102539
# GRICA with n =  1000
# Time taken:  0.11403703689575195
# GRICA with n =  100000
# Time taken:  0.7734050750732422
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.10502290725708008
# GRICA with n =  1000
# Time taken:  0.11735010147094727
# GRICA with n =  100000
# Time taken:  0.8041419982910156
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.10619187355041504
# GRICA with n =  1000
# Time taken:  0.11870908737182617
# GRICA with n =  100000
# Time taken:  0.7706167697906494
# GRICA with n =  10000000
# Time taken:  1.1920928955078125e-06
# GRICA with n =  10
# Time taken:  0.10444498062133789
# GRICA with n =  1000
# Time taken:  0.12039518356323242
# GRICA with n =  100000
# Time taken:  0.7705399990081787
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.12267684936523438
# GRICA with n =  1000
# Time taken:  0.1167149543762207
# GRICA with n =  100000
# Time taken:  0.7819678783416748
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.10568928718566895
# GRICA with n =  1000
# Time taken:  0.12036609649658203
# GRICA with n =  100000
# Time taken:  0.7732620239257812
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.10460400581359863
# GRICA with n =  1000
# Time taken:  0.11471891403198242
# GRICA with n =  100000
# Time taken:  0.7832241058349609
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.10674190521240234
# GRICA with n =  1000
# Time taken:  0.11746907234191895
# GRICA with n =  100000
# Time taken:  0.8534269332885742
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.10085916519165039
# GRICA with n =  1000
# Time taken:  0.11843609809875488
# GRICA with n =  100000
# Time taken:  0.8692972660064697
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.10514402389526367
# GRICA with n =  1000
# Time taken:  0.11398077011108398
# GRICA with n =  100000
# Time taken:  0.7633237838745117
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.10834980010986328
# GRICA with n =  1000
# Time taken:  0.11955118179321289
# GRICA with n =  100000
# Time taken:  0.9236350059509277
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.1050870418548584
# GRICA with n =  1000
# Time taken:  0.12495803833007812
# GRICA with n =  100000
# Time taken:  0.8867371082305908
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.10902595520019531
# GRICA with n =  1000
# Time taken:  0.11535406112670898
# GRICA with n =  100000
# Time taken:  0.8375511169433594
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.10005021095275879
# GRICA with n =  1000
# Time taken:  0.11965608596801758
# GRICA with n =  100000
# Time taken:  0.764272928237915
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.10396289825439453
# GRICA with n =  1000
# Time taken:  0.11741423606872559
# GRICA with n =  100000
# Time taken:  0.7592208385467529
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.09935522079467773
# GRICA with n =  1000
# Time taken:  0.11296582221984863
# GRICA with n =  100000
# Time taken:  0.7606897354125977
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.10546684265136719
# GRICA with n =  1000
# Time taken:  0.11263489723205566
# GRICA with n =  100000
# Time taken:  0.7613167762756348
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.09970998764038086
# GRICA with n =  1000
# Time taken:  0.11348605155944824
# GRICA with n =  100000
# Time taken:  0.7602999210357666
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.10010004043579102
# GRICA with n =  1000
# Time taken:  0.11739015579223633
# GRICA with n =  100000
# Time taken:  0.7644670009613037
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.10408806800842285
# GRICA with n =  1000
# Time taken:  0.1129310131072998
# GRICA with n =  100000
# Time taken:  0.7619631290435791
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.09998011589050293
# GRICA with n =  1000
# Time taken:  0.11752176284790039
# GRICA with n =  100000
# Time taken:  0.7929739952087402
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.10425806045532227
# GRICA with n =  1000
# Time taken:  0.11721587181091309
# GRICA with n =  100000
# Time taken:  0.7687580585479736
# GRICA with n =  10000000
# Time taken:  1.1920928955078125e-06
# GRICA with n =  10
# Time taken:  0.10434222221374512
# GRICA with n =  1000
# Time taken:  0.1167900562286377
# GRICA with n =  100000
# Time taken:  0.7595069408416748
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.09894394874572754
# GRICA with n =  1000
# Time taken:  0.11671781539916992
# GRICA with n =  100000
# Time taken:  0.7600607872009277
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.09977889060974121
# GRICA with n =  1000
# Time taken:  0.1180112361907959
# GRICA with n =  100000
# Time taken:  0.7605938911437988
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.10403704643249512
# GRICA with n =  1000
# Time taken:  0.1141061782836914
# GRICA with n =  100000
# Time taken:  0.7567002773284912
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.10534095764160156
# GRICA with n =  1000
# Time taken:  0.11231398582458496
# GRICA with n =  100000
# Time taken:  0.758112907409668
# GRICA with n =  10000000
# Time taken:  1.1920928955078125e-06
# GRICA with n =  10
# Time taken:  0.10074019432067871
# GRICA with n =  1000
# Time taken:  0.11270403861999512
# GRICA with n =  100000
# Time taken:  0.757328987121582
# GRICA with n =  10000000
# Time taken:  1.1920928955078125e-06
# GRICA with n =  10
# Time taken:  0.09951210021972656
# GRICA with n =  1000
# Time taken:  0.1133720874786377
# GRICA with n =  100000
# Time taken:  0.763293981552124
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.10507369041442871
# GRICA with n =  1000
# Time taken:  0.1168508529663086
# GRICA with n =  100000
# Time taken:  0.7668468952178955
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.1030569076538086
# GRICA with n =  1000
# Time taken:  0.11250925064086914
# GRICA with n =  100000
# Time taken:  0.7593090534210205
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.10516810417175293
# GRICA with n =  1000
# Time taken:  0.11723875999450684
# GRICA with n =  100000
# Time taken:  0.7590909004211426
# GRICA with n =  10000000
# Time taken:  1.1920928955078125e-06
# GRICA with n =  10
# Time taken:  0.10436487197875977
# GRICA with n =  1000
# Time taken:  0.11385798454284668
# GRICA with n =  100000
# Time taken:  0.7643601894378662
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.09978795051574707
# GRICA with n =  1000
# Time taken:  0.11848592758178711
# GRICA with n =  100000
# Time taken:  0.7632219791412354
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.10520386695861816
# GRICA with n =  1000
# Time taken:  0.11216092109680176
# GRICA with n =  100000
# Time taken:  0.760714054107666
# GRICA with n =  10000000
# Time taken:  0.0
# GRICA with n =  10
# Time taken:  0.09925389289855957
# GRICA with n =  1000
# Time taken:  0.11271071434020996
# GRICA with n =  100000
# Time taken:  0.7580728530883789
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.09928297996520996
# GRICA with n =  1000
# Time taken:  0.1119990348815918
# GRICA with n =  100000
# Time taken:  0.7630147933959961
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07
# GRICA with n =  10
# Time taken:  0.09988808631896973
# GRICA with n =  1000
# Time taken:  0.11255812644958496
# GRICA with n =  100000
# Time taken:  0.7659378051757812
# GRICA with n =  10000000
# Time taken:  9.5367431640625e-07

# %%
results_df_2_latents.to_csv('Data/beta_cm_2_latent.csv', index=False)

# %%
results_df_2_latents = pd.read_csv('Data/beta_cm_2_latent.csv')

# %%
import matplotlib.pyplot as plt

results_df_2_latents["Error"] = np.abs((results_df_2_latents['Effect Estimate'] - results_df_2_latents["True Effect"])/results_df_2_latents["True Effect"])  # Calculate the error
results_df_2_latents["Cross Moment Error"] = np.abs((results_df_2_latents['Cross Moment Effect Estimate'] - results_df_2_latents["True Effect"])/results_df_2_latents["True Effect"])  # Calculate the error
results_df_2_latents["GRICA Error"] = np.abs((results_df_2_latents['GRICA Effect Estimate'] - results_df_2_latents["True Effect"])/results_df_2_latents["True Effect"])  # Calculate the error


# Group the results by sample size and calculate the mean
median_results = results_df_2_latents.groupby('Sample Size').median()
quantile_results = results_df_2_latents.groupby('Sample Size').quantile(0.25)
quantile_results2 = results_df_2_latents.groupby('Sample Size').quantile(0.75)

SMALL_SIZE = 8
MEDIUM_SIZE = 14
BIGGER_SIZE = 16

plt.rc('font', size=BIGGER_SIZE)
plt.rc('axes', titlesize=BIGGER_SIZE)
plt.rc('axes', labelsize=BIGGER_SIZE)
plt.rc('xtick', labelsize=BIGGER_SIZE)
plt.rc('ytick', labelsize=BIGGER_SIZE)
plt.rc('legend', fontsize=MEDIUM_SIZE)
plt.rc('figure', titlesize=BIGGER_SIZE)

# Plot the results

# Plot the mean results
plt.yscale('log')
plt.xscale('log')
plt.plot(median_results.index, median_results["Error"],
         label='Cumulant',
         color = "blue")

plt.fill_between(median_results.index, quantile_results["Error"], quantile_results2["Error"], alpha=0.2, color = "blue")

plt.plot(median_results.index, median_results["Cross Moment Error"],
            label='Cross Moment',
            color = "red")

plt.fill_between(median_results.index, quantile_results["Cross Moment Error"], quantile_results2["Cross Moment Error"], alpha=0.2, color = "red")

plt.plot(median_results.index, median_results["GRICA Error"],
            label='GRICA',
            color = "green")

plt.fill_between(median_results.index, quantile_results["GRICA Error"], quantile_results2["GRICA Error"], alpha=0.2, color = "green")


plt.xlabel('Sample Size (LOG-scale)')
plt.ylabel('Error (LOG-scale)')
plt.title(f"Distribution: Beta, Graph: $\mathcal{{G}}_2$")
plt.legend()
plt.legend(loc="lower left")
plt.grid()
plt.savefig("Figures/beta_G2_samples_vs_err.png", bbox_inches="tight")
plt.show()

# %%
results_df_2_latents.to_csv('Data/beta_cm_2_latent.csv', index=False)
